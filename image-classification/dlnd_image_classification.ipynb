# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 20
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 20:
# Image - Min Value: 34 Max Value: 228
# Image - Shape: (32, 32, 3)
# Label - Label Id: 4 Name: deer

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x_min = x.min()
    Range = x.max() - x_min
    return (x-x_min)/Range
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    z = np.zeros((len(x),10),dtype=int)
    for idx,i in enumerate(x):
        z[idx,i] = 1
    return z


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    x,y,d = image_shape
    return tf.placeholder(shape=(None,x,y,d),dtype=tf.float32,name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(shape=(None,n_classes),dtype=tf.int32,name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(name='keep_prob',dtype=tf.float32)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    conv_strides = (1,conv_strides[0],conv_strides[1],1)
    pool_ksize = [1,pool_ksize[0],pool_ksize[1],1]
    pool_strides = [1,pool_strides[0],pool_strides[1],1]
    
    w_shape = (conv_ksize[0],conv_ksize[1],x_tensor.get_shape().as_list()[-1],conv_num_outputs)
    #n_param = w_shape[0]*w_shape[1]*w_shape[2]*w_shape[3]
    
    w = tf.Variable(tf.truncated_normal(stddev=0.1,shape=w_shape))
    b = tf.Variable(tf.zeros(conv_num_outputs)) 
    
    c = tf.nn.conv2d(x_tensor,w,conv_strides,padding='SAME')
    c = tf.nn.relu(tf.nn.bias_add(c,b))
    
    p = tf.nn.max_pool(c,ksize=pool_ksize,strides=pool_strides,padding='SAME')
    
    # TODO: Implement Function
    return p


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape =  tf.shape(x_tensor)
    shape_int = x_tensor.get_shape().as_list()
    dim0=shape[0]
    dim1=shape_int[1] * shape_int[2] * shape_int[3]
    return tf.reshape(x_tensor,[dim0,dim1])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_dim1 = x_tensor.get_shape().as_list()[1]
    w = tf.Variable(tf.truncated_normal([x_dim1,num_outputs],stddev=.1))
    b = tf.Variable(tf.zeros([num_outputs]))
    
    return tf.nn.relu(tf.add(tf.matmul(x_tensor,w),b))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_dim1 = x_tensor.get_shape().as_list()[1]
    w = tf.Variable(tf.truncated_normal([x_dim1,num_outputs],stddev=.1))
    b = tf.Variable(tf.zeros([num_outputs]))
    
    return tf.add(tf.matmul(x_tensor,w),b)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    out = x
    out = conv2d_maxpool(out,32,[5,5],[1,1],[3,3],[2,2])
    out = conv2d_maxpool(out,64,[5,5],[1,1],[3,3],[2,2])
    out = tf.nn.dropout(out,keep_prob)
    out = conv2d_maxpool(out,128,[3,3],[1,1],[3,3],[2,2])
    out = tf.nn.dropout(out,keep_prob)
    out = conv2d_maxpool(out,256,[3,3],[1,1],[3,3],[2,2])
    out = tf.nn.dropout(out,keep_prob)
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    out = flatten(out)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    out = fully_conn(out,64)
    out = tf.nn.dropout(out,keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(out,10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    opt = session.run([optimizer],feed_dict={keep_prob:keep_probability,x:feature_batch,y:label_batch})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    val_acc = session.run(accuracy,feed_dict={x:valid_features,y:valid_labels,keep_prob:1})
    cost = session.run(cost,feed_dict={x:feature_batch,y:label_batch,keep_prob:1})
    print('training cost: %.4f , validation accuracy: %.4f'%(cost,val_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability = 0.7

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  training cost: 2.3023 , validation accuracy: 0.0998
# Epoch  2, CIFAR-10 Batch 1:  training cost: 2.2918 , validation accuracy: 0.0830
# Epoch  3, CIFAR-10 Batch 1:  training cost: 2.2333 , validation accuracy: 0.1266
# Epoch  4, CIFAR-10 Batch 1:  training cost: 2.2181 , validation accuracy: 0.2112
# Epoch  5, CIFAR-10 Batch 1:  training cost: 2.1156 , validation accuracy: 0.2448
# Epoch  6, CIFAR-10 Batch 1:  training cost: 2.0372 , validation accuracy: 0.2798
# Epoch  7, CIFAR-10 Batch 1:  training cost: 1.9144 , validation accuracy: 0.3348
# Epoch  8, CIFAR-10 Batch 1:  training cost: 1.8569 , validation accuracy: 0.3578
# Epoch  9, CIFAR-10 Batch 1:  training cost: 1.7781 , validation accuracy: 0.3790
# Epoch 10, CIFAR-10 Batch 1:  training cost: 1.6693 , validation accuracy: 0.3882
# Epoch 11, CIFAR-10 Batch 1:  training cost: 1.6358 , validation accuracy: 0.4262
# Epoch 12, CIFAR-10 Batch 1:  training cost: 1.5242 , validation accuracy: 0.4294
# Epoch 13, CIFAR-10 Batch 1:  training cost: 1.4919 , validation accuracy: 0.4572
# Epoch 14, CIFAR-10 Batch 1:  training cost: 1.4531 , validation accuracy: 0.4510
# Epoch 15, CIFAR-10 Batch 1:  training cost: 1.3614 , validation accuracy: 0.4844
# Epoch 16, CIFAR-10 Batch 1:  training cost: 1.2984 , validation accuracy: 0.4998
# Epoch 17, CIFAR-10 Batch 1:  training cost: 1.2699 , validation accuracy: 0.5046
# Epoch 18, CIFAR-10 Batch 1:  training cost: 1.1696 , validation accuracy: 0.5082
# Epoch 19, CIFAR-10 Batch 1:  training cost: 1.1316 , validation accuracy: 0.5134
# Epoch 20, CIFAR-10 Batch 1:  training cost: 1.0531 , validation accuracy: 0.5288
# Epoch 21, CIFAR-10 Batch 1:  training cost: 1.0440 , validation accuracy: 0.5300
# Epoch 22, CIFAR-10 Batch 1:  training cost: 1.0203 , validation accuracy: 0.5322
# Epoch 23, CIFAR-10 Batch 1:  training cost: 0.9352 , validation accuracy: 0.5472
# Epoch 24, CIFAR-10 Batch 1:  training cost: 0.8754 , validation accuracy: 0.5538
# Epoch 25, CIFAR-10 Batch 1:  training cost: 0.8345 , validation accuracy: 0.5598
# Epoch 26, CIFAR-10 Batch 1:  training cost: 0.8084 , validation accuracy: 0.5452
# Epoch 27, CIFAR-10 Batch 1:  training cost: 0.8222 , validation accuracy: 0.5504
# Epoch 28, CIFAR-10 Batch 1:  training cost: 0.7558 , validation accuracy: 0.5588
# Epoch 29, CIFAR-10 Batch 1:  training cost: 0.7360 , validation accuracy: 0.5518
# Epoch 30, CIFAR-10 Batch 1:  training cost: 0.6725 , validation accuracy: 0.5738
# Epoch 31, CIFAR-10 Batch 1:  training cost: 0.6840 , validation accuracy: 0.5674
# Epoch 32, CIFAR-10 Batch 1:  training cost: 0.5780 , validation accuracy: 0.5804
# Epoch 33, CIFAR-10 Batch 1:  training cost: 0.5724 , validation accuracy: 0.5766
# Epoch 34, CIFAR-10 Batch 1:  training cost: 0.5489 , validation accuracy: 0.5728
# Epoch 35, CIFAR-10 Batch 1:  training cost: 0.4998 , validation accuracy: 0.5818
# Epoch 36, CIFAR-10 Batch 1:  training cost: 0.4969 , validation accuracy: 0.5796
# Epoch 37, CIFAR-10 Batch 1:  training cost: 0.5122 , validation accuracy: 0.5640
# Epoch 38, CIFAR-10 Batch 1:  training cost: 0.4711 , validation accuracy: 0.5850
# Epoch 39, CIFAR-10 Batch 1:  training cost: 0.4670 , validation accuracy: 0.5620
# Epoch 40, CIFAR-10 Batch 1:  training cost: 0.4326 , validation accuracy: 0.6022
# Epoch 41, CIFAR-10 Batch 1:  training cost: 0.4305 , validation accuracy: 0.5976
# Epoch 42, CIFAR-10 Batch 1:  training cost: 0.4222 , validation accuracy: 0.6018
# Epoch 43, CIFAR-10 Batch 1:  training cost: 0.3897 , validation accuracy: 0.5976
# Epoch 44, CIFAR-10 Batch 1:  training cost: 0.3882 , validation accuracy: 0.5952
# Epoch 45, CIFAR-10 Batch 1:  training cost: 0.3728 , validation accuracy: 0.5990
# Epoch 46, CIFAR-10 Batch 1:  training cost: 0.3605 , validation accuracy: 0.6074
# Epoch 47, CIFAR-10 Batch 1:  training cost: 0.3513 , validation accuracy: 0.6140
# Epoch 48, CIFAR-10 Batch 1:  training cost: 0.3344 , validation accuracy: 0.6072
# Epoch 49, CIFAR-10 Batch 1:  training cost: 0.3556 , validation accuracy: 0.5910
# Epoch 50, CIFAR-10 Batch 1:  training cost: 0.3105 , validation accuracy: 0.6180
# Epoch 51, CIFAR-10 Batch 1:  training cost: 0.3572 , validation accuracy: 0.6046
# Epoch 52, CIFAR-10 Batch 1:  training cost: 0.2856 , validation accuracy: 0.6240
# Epoch 53, CIFAR-10 Batch 1:  training cost: 0.2989 , validation accuracy: 0.6100
# Epoch 54, CIFAR-10 Batch 1:  training cost: 0.3089 , validation accuracy: 0.6098
# Epoch 55, CIFAR-10 Batch 1:  training cost: 0.2992 , validation accuracy: 0.6090
# Epoch 56, CIFAR-10 Batch 1:  training cost: 0.2449 , validation accuracy: 0.6098
# Epoch 57, CIFAR-10 Batch 1:  training cost: 0.2276 , validation accuracy: 0.6244
# Epoch 58, CIFAR-10 Batch 1:  training cost: 0.2714 , validation accuracy: 0.6166
# Epoch 59, CIFAR-10 Batch 1:  training cost: 0.2489 , validation accuracy: 0.6196
# Epoch 60, CIFAR-10 Batch 1:  training cost: 0.2250 , validation accuracy: 0.6198
# Epoch 61, CIFAR-10 Batch 1:  training cost: 0.2291 , validation accuracy: 0.6248
# Epoch 62, CIFAR-10 Batch 1:  training cost: 0.1899 , validation accuracy: 0.6106
# Epoch 63, CIFAR-10 Batch 1:  training cost: 0.1989 , validation accuracy: 0.6276
# Epoch 64, CIFAR-10 Batch 1:  training cost: 0.1863 , validation accuracy: 0.6230
# Epoch 65, CIFAR-10 Batch 1:  training cost: 0.1880 , validation accuracy: 0.6142
# Epoch 66, CIFAR-10 Batch 1:  training cost: 0.1992 , validation accuracy: 0.6262
# Epoch 67, CIFAR-10 Batch 1:  training cost: 0.1942 , validation accuracy: 0.6140
# Epoch 68, CIFAR-10 Batch 1:  training cost: 0.1873 , validation accuracy: 0.6100
# Epoch 69, CIFAR-10 Batch 1:  training cost: 0.1406 , validation accuracy: 0.6352
# Epoch 70, CIFAR-10 Batch 1:  training cost: 0.1571 , validation accuracy: 0.6258
# Epoch 71, CIFAR-10 Batch 1:  training cost: 0.1404 , validation accuracy: 0.6146
# Epoch 72, CIFAR-10 Batch 1:  training cost: 0.1625 , validation accuracy: 0.6220
# Epoch 73, CIFAR-10 Batch 1:  training cost: 0.1270 , validation accuracy: 0.6230
# Epoch 74, CIFAR-10 Batch 1:  training cost: 0.1032 , validation accuracy: 0.6336
# Epoch 75, CIFAR-10 Batch 1:  training cost: 0.0901 , validation accuracy: 0.6318
# Epoch 76, CIFAR-10 Batch 1:  training cost: 0.0937 , validation accuracy: 0.6258
# Epoch 77, CIFAR-10 Batch 1:  training cost: 0.0995 , validation accuracy: 0.6192
# Epoch 78, CIFAR-10 Batch 1:  training cost: 0.0852 , validation accuracy: 0.6142
# Epoch 79, CIFAR-10 Batch 1:  training cost: 0.1056 , validation accuracy: 0.6348
# Epoch 80, CIFAR-10 Batch 1:  training cost: 0.0940 , validation accuracy: 0.6222
# Epoch 81, CIFAR-10 Batch 1:  training cost: 0.0881 , validation accuracy: 0.6174
# Epoch 82, CIFAR-10 Batch 1:  training cost: 0.0722 , validation accuracy: 0.6270
# Epoch 83, CIFAR-10 Batch 1:  training cost: 0.0653 , validation accuracy: 0.6232
# Epoch 84, CIFAR-10 Batch 1:  training cost: 0.0650 , validation accuracy: 0.6292
# Epoch 85, CIFAR-10 Batch 1:  training cost: 0.0721 , validation accuracy: 0.6152
# Epoch 86, CIFAR-10 Batch 1:  training cost: 0.0576 , validation accuracy: 0.6234
# Epoch 87, CIFAR-10 Batch 1:  training cost: 0.0808 , validation accuracy: 0.5948
# Epoch 88, CIFAR-10 Batch 1:  training cost: 0.0757 , validation accuracy: 0.6116
# Epoch 89, CIFAR-10 Batch 1:  training cost: 0.0454 , validation accuracy: 0.6174
# Epoch 90, CIFAR-10 Batch 1:  training cost: 0.0631 , validation accuracy: 0.6248
# Epoch 91, CIFAR-10 Batch 1:  training cost: 0.0493 , validation accuracy: 0.6284
# Epoch 92, CIFAR-10 Batch 1:  training cost: 0.0401 , validation accuracy: 0.6188
# Epoch 93, CIFAR-10 Batch 1:  training cost: 0.0563 , validation accuracy: 0.6206
# Epoch 94, CIFAR-10 Batch 1:  training cost: 0.0442 , validation accuracy: 0.6236
# Epoch 95, CIFAR-10 Batch 1:  training cost: 0.0381 , validation accuracy: 0.6248
# Epoch 96, CIFAR-10 Batch 1:  training cost: 0.0538 , validation accuracy: 0.6258
# Epoch 97, CIFAR-10 Batch 1:  training cost: 0.0533 , validation accuracy: 0.6182
# Epoch 98, CIFAR-10 Batch 1:  training cost: 0.0370 , validation accuracy: 0.6262
# Epoch 99, CIFAR-10 Batch 1:  training cost: 0.0440 , validation accuracy: 0.6316
# Epoch 100, CIFAR-10 Batch 1:  training cost: 0.0323 , validation accuracy: 0.6332

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  training cost: 2.3027 , validation accuracy: 0.0946
# Epoch  1, CIFAR-10 Batch 2:  training cost: 2.2631 , validation accuracy: 0.1684
# Epoch  1, CIFAR-10 Batch 3:  training cost: 2.1344 , validation accuracy: 0.2246
# Epoch  1, CIFAR-10 Batch 4:  training cost: 1.9475 , validation accuracy: 0.3046
# Epoch  1, CIFAR-10 Batch 5:  training cost: 1.8307 , validation accuracy: 0.3334
# Epoch  2, CIFAR-10 Batch 1:  training cost: 1.9059 , validation accuracy: 0.3716
# Epoch  2, CIFAR-10 Batch 2:  training cost: 1.7581 , validation accuracy: 0.3756
# Epoch  2, CIFAR-10 Batch 3:  training cost: 1.5104 , validation accuracy: 0.4120
# Epoch  2, CIFAR-10 Batch 4:  training cost: 1.6739 , validation accuracy: 0.4306
# Epoch  2, CIFAR-10 Batch 5:  training cost: 1.6121 , validation accuracy: 0.4432
# Epoch  3, CIFAR-10 Batch 1:  training cost: 1.5526 , validation accuracy: 0.4568
# Epoch  3, CIFAR-10 Batch 2:  training cost: 1.5176 , validation accuracy: 0.4618
# Epoch  3, CIFAR-10 Batch 3:  training cost: 1.3186 , validation accuracy: 0.4828
# Epoch  3, CIFAR-10 Batch 4:  training cost: 1.4815 , validation accuracy: 0.4744
# Epoch  3, CIFAR-10 Batch 5:  training cost: 1.4871 , validation accuracy: 0.4832
# Epoch  4, CIFAR-10 Batch 1:  training cost: 1.3755 , validation accuracy: 0.5232
# Epoch  4, CIFAR-10 Batch 2:  training cost: 1.3631 , validation accuracy: 0.4968
# Epoch  4, CIFAR-10 Batch 3:  training cost: 1.2366 , validation accuracy: 0.5094
# Epoch  4, CIFAR-10 Batch 4:  training cost: 1.3278 , validation accuracy: 0.5312
# Epoch  4, CIFAR-10 Batch 5:  training cost: 1.2935 , validation accuracy: 0.5456
# Epoch  5, CIFAR-10 Batch 1:  training cost: 1.2138 , validation accuracy: 0.5494
# Epoch  5, CIFAR-10 Batch 2:  training cost: 1.2350 , validation accuracy: 0.5642
# Epoch  5, CIFAR-10 Batch 3:  training cost: 1.0948 , validation accuracy: 0.5512
# Epoch  5, CIFAR-10 Batch 4:  training cost: 1.1477 , validation accuracy: 0.5856
# Epoch  5, CIFAR-10 Batch 5:  training cost: 1.2150 , validation accuracy: 0.5796
# Epoch  6, CIFAR-10 Batch 1:  training cost: 1.1199 , validation accuracy: 0.5760
# Epoch  6, CIFAR-10 Batch 2:  training cost: 1.1431 , validation accuracy: 0.5936
# Epoch  6, CIFAR-10 Batch 3:  training cost: 0.9493 , validation accuracy: 0.5748
# Epoch  6, CIFAR-10 Batch 4:  training cost: 1.1641 , validation accuracy: 0.5940
# Epoch  6, CIFAR-10 Batch 5:  training cost: 1.0724 , validation accuracy: 0.6032
# Epoch  7, CIFAR-10 Batch 1:  training cost: 0.9695 , validation accuracy: 0.6174
# Epoch  7, CIFAR-10 Batch 2:  training cost: 1.0404 , validation accuracy: 0.6238
# Epoch  7, CIFAR-10 Batch 3:  training cost: 0.8951 , validation accuracy: 0.6072
# Epoch  7, CIFAR-10 Batch 4:  training cost: 1.0260 , validation accuracy: 0.6156
# Epoch  7, CIFAR-10 Batch 5:  training cost: 1.0174 , validation accuracy: 0.6096
# Epoch  8, CIFAR-10 Batch 1:  training cost: 0.9095 , validation accuracy: 0.6220
# Epoch  8, CIFAR-10 Batch 2:  training cost: 0.9513 , validation accuracy: 0.6250
# Epoch  8, CIFAR-10 Batch 3:  training cost: 0.7934 , validation accuracy: 0.6296
# Epoch  8, CIFAR-10 Batch 4:  training cost: 0.8889 , validation accuracy: 0.6278
# Epoch  8, CIFAR-10 Batch 5:  training cost: 0.8707 , validation accuracy: 0.6474
# Epoch  9, CIFAR-10 Batch 1:  training cost: 0.8962 , validation accuracy: 0.6314
# Epoch  9, CIFAR-10 Batch 2:  training cost: 0.9580 , validation accuracy: 0.6466
# Epoch  9, CIFAR-10 Batch 3:  training cost: 0.7532 , validation accuracy: 0.6464
# Epoch  9, CIFAR-10 Batch 4:  training cost: 0.8324 , validation accuracy: 0.6546
# Epoch  9, CIFAR-10 Batch 5:  training cost: 0.8102 , validation accuracy: 0.6476
# Epoch 10, CIFAR-10 Batch 1:  training cost: 0.8715 , validation accuracy: 0.6414
# Epoch 10, CIFAR-10 Batch 2:  training cost: 0.7603 , validation accuracy: 0.6644
# Epoch 10, CIFAR-10 Batch 3:  training cost: 0.7289 , validation accuracy: 0.6562
# Epoch 10, CIFAR-10 Batch 4:  training cost: 0.7569 , validation accuracy: 0.6542
# Epoch 10, CIFAR-10 Batch 5:  training cost: 0.7075 , validation accuracy: 0.6640
# Epoch 11, CIFAR-10 Batch 1:  training cost: 0.8312 , validation accuracy: 0.6548
# Epoch 11, CIFAR-10 Batch 2:  training cost: 0.7832 , validation accuracy: 0.6756
# Epoch 11, CIFAR-10 Batch 3:  training cost: 0.6332 , validation accuracy: 0.6732
# Epoch 11, CIFAR-10 Batch 4:  training cost: 0.6517 , validation accuracy: 0.6774
# Epoch 11, CIFAR-10 Batch 5:  training cost: 0.7153 , validation accuracy: 0.6748
# Epoch 12, CIFAR-10 Batch 1:  training cost: 0.6861 , validation accuracy: 0.6852
# Epoch 12, CIFAR-10 Batch 2:  training cost: 0.7066 , validation accuracy: 0.6826
# Epoch 12, CIFAR-10 Batch 3:  training cost: 0.5885 , validation accuracy: 0.6800
# Epoch 12, CIFAR-10 Batch 4:  training cost: 0.6029 , validation accuracy: 0.6890
# Epoch 12, CIFAR-10 Batch 5:  training cost: 0.6801 , validation accuracy: 0.6776
# Epoch 13, CIFAR-10 Batch 1:  training cost: 0.6363 , validation accuracy: 0.6866
# Epoch 13, CIFAR-10 Batch 2:  training cost: 0.6817 , validation accuracy: 0.6936
# Epoch 13, CIFAR-10 Batch 3:  training cost: 0.5586 , validation accuracy: 0.6736
# Epoch 13, CIFAR-10 Batch 4:  training cost: 0.5406 , validation accuracy: 0.6964
# Epoch 13, CIFAR-10 Batch 5:  training cost: 0.6114 , validation accuracy: 0.6914
# Epoch 14, CIFAR-10 Batch 1:  training cost: 0.6624 , validation accuracy: 0.6958
# Epoch 14, CIFAR-10 Batch 2:  training cost: 0.6179 , validation accuracy: 0.6892
# Epoch 14, CIFAR-10 Batch 3:  training cost: 0.5614 , validation accuracy: 0.6844
# Epoch 14, CIFAR-10 Batch 4:  training cost: 0.5838 , validation accuracy: 0.6972
# Epoch 14, CIFAR-10 Batch 5:  training cost: 0.4687 , validation accuracy: 0.6942
# Epoch 15, CIFAR-10 Batch 1:  training cost: 0.6089 , validation accuracy: 0.7038
# Epoch 15, CIFAR-10 Batch 2:  training cost: 0.5912 , validation accuracy: 0.6952
# Epoch 15, CIFAR-10 Batch 3:  training cost: 0.4445 , validation accuracy: 0.7064
# Epoch 15, CIFAR-10 Batch 4:  training cost: 0.5459 , validation accuracy: 0.6952
# Epoch 15, CIFAR-10 Batch 5:  training cost: 0.4659 , validation accuracy: 0.7182
# Epoch 16, CIFAR-10 Batch 1:  training cost: 0.5340 , validation accuracy: 0.7118
# Epoch 16, CIFAR-10 Batch 2:  training cost: 0.5674 , validation accuracy: 0.6994
# Epoch 16, CIFAR-10 Batch 3:  training cost: 0.4417 , validation accuracy: 0.7000
# Epoch 16, CIFAR-10 Batch 4:  training cost: 0.4512 , validation accuracy: 0.7092
# Epoch 16, CIFAR-10 Batch 5:  training cost: 0.4230 , validation accuracy: 0.7064
# Epoch 17, CIFAR-10 Batch 1:  training cost: 0.4978 , validation accuracy: 0.7182
# Epoch 17, CIFAR-10 Batch 2:  training cost: 0.4968 , validation accuracy: 0.7114
# Epoch 17, CIFAR-10 Batch 3:  training cost: 0.4242 , validation accuracy: 0.7168
# Epoch 17, CIFAR-10 Batch 4:  training cost: 0.4138 , validation accuracy: 0.7288
# Epoch 17, CIFAR-10 Batch 5:  training cost: 0.4608 , validation accuracy: 0.6912
# Epoch 18, CIFAR-10 Batch 1:  training cost: 0.5139 , validation accuracy: 0.7236
# Epoch 18, CIFAR-10 Batch 2:  training cost: 0.5069 , validation accuracy: 0.7208
# Epoch 18, CIFAR-10 Batch 3:  training cost: 0.3286 , validation accuracy: 0.7280
# Epoch 18, CIFAR-10 Batch 4:  training cost: 0.3842 , validation accuracy: 0.7178
# Epoch 18, CIFAR-10 Batch 5:  training cost: 0.3517 , validation accuracy: 0.7150
# Epoch 19, CIFAR-10 Batch 1:  training cost: 0.4391 , validation accuracy: 0.7182
# Epoch 19, CIFAR-10 Batch 2:  training cost: 0.4691 , validation accuracy: 0.7186
# Epoch 19, CIFAR-10 Batch 3:  training cost: 0.4191 , validation accuracy: 0.7038
# Epoch 19, CIFAR-10 Batch 4:  training cost: 0.3666 , validation accuracy: 0.7292
# Epoch 19, CIFAR-10 Batch 5:  training cost: 0.4348 , validation accuracy: 0.7026
# Epoch 20, CIFAR-10 Batch 1:  training cost: 0.4429 , validation accuracy: 0.7212
# Epoch 20, CIFAR-10 Batch 2:  training cost: 0.4267 , validation accuracy: 0.7308
# Epoch 20, CIFAR-10 Batch 3:  training cost: 0.3208 , validation accuracy: 0.7152
# Epoch 20, CIFAR-10 Batch 4:  training cost: 0.3703 , validation accuracy: 0.7300
# Epoch 20, CIFAR-10 Batch 5:  training cost: 0.3746 , validation accuracy: 0.7270
# Epoch 21, CIFAR-10 Batch 1:  training cost: 0.4383 , validation accuracy: 0.7170
# Epoch 21, CIFAR-10 Batch 2:  training cost: 0.3898 , validation accuracy: 0.7296
# Epoch 21, CIFAR-10 Batch 3:  training cost: 0.3215 , validation accuracy: 0.7380
# Epoch 21, CIFAR-10 Batch 4:  training cost: 0.3316 , validation accuracy: 0.7466
# Epoch 21, CIFAR-10 Batch 5:  training cost: 0.3159 , validation accuracy: 0.7300
# Epoch 22, CIFAR-10 Batch 1:  training cost: 0.3962 , validation accuracy: 0.7400
# Epoch 22, CIFAR-10 Batch 2:  training cost: 0.3476 , validation accuracy: 0.7364
# Epoch 22, CIFAR-10 Batch 3:  training cost: 0.2495 , validation accuracy: 0.7322
# Epoch 22, CIFAR-10 Batch 4:  training cost: 0.3390 , validation accuracy: 0.7332
# Epoch 22, CIFAR-10 Batch 5:  training cost: 0.3138 , validation accuracy: 0.7346
# Epoch 23, CIFAR-10 Batch 1:  training cost: 0.3491 , validation accuracy: 0.7290
# Epoch 23, CIFAR-10 Batch 2:  training cost: 0.3810 , validation accuracy: 0.7364
# Epoch 23, CIFAR-10 Batch 3:  training cost: 0.2864 , validation accuracy: 0.7302
# Epoch 23, CIFAR-10 Batch 4:  training cost: 0.3178 , validation accuracy: 0.7462
# Epoch 23, CIFAR-10 Batch 5:  training cost: 0.2752 , validation accuracy: 0.7242
# Epoch 24, CIFAR-10 Batch 1:  training cost: 0.3272 , validation accuracy: 0.7356
# Epoch 24, CIFAR-10 Batch 2:  training cost: 0.3864 , validation accuracy: 0.7392
# Epoch 24, CIFAR-10 Batch 3:  training cost: 0.3008 , validation accuracy: 0.7164
# Epoch 24, CIFAR-10 Batch 4:  training cost: 0.2709 , validation accuracy: 0.7306
# Epoch 24, CIFAR-10 Batch 5:  training cost: 0.2820 , validation accuracy: 0.7394
# Epoch 25, CIFAR-10 Batch 1:  training cost: 0.3115 , validation accuracy: 0.7446
# Epoch 25, CIFAR-10 Batch 2:  training cost: 0.3368 , validation accuracy: 0.7398
# Epoch 25, CIFAR-10 Batch 3:  training cost: 0.2565 , validation accuracy: 0.7406
# Epoch 25, CIFAR-10 Batch 4:  training cost: 0.3011 , validation accuracy: 0.7406
# Epoch 25, CIFAR-10 Batch 5:  training cost: 0.2675 , validation accuracy: 0.7448
# Epoch 26, CIFAR-10 Batch 1:  training cost: 0.3167 , validation accuracy: 0.7404
# Epoch 26, CIFAR-10 Batch 2:  training cost: 0.2949 , validation accuracy: 0.7536
# Epoch 26, CIFAR-10 Batch 3:  training cost: 0.2238 , validation accuracy: 0.7490
# Epoch 26, CIFAR-10 Batch 4:  training cost: 0.2548 , validation accuracy: 0.7506
# Epoch 26, CIFAR-10 Batch 5:  training cost: 0.2700 , validation accuracy: 0.7456
# Epoch 27, CIFAR-10 Batch 1:  training cost: 0.3012 , validation accuracy: 0.7224
# Epoch 27, CIFAR-10 Batch 2:  training cost: 0.2456 , validation accuracy: 0.7506
# Epoch 27, CIFAR-10 Batch 3:  training cost: 0.1841 , validation accuracy: 0.7400
# Epoch 27, CIFAR-10 Batch 4:  training cost: 0.2641 , validation accuracy: 0.7462
# Epoch 27, CIFAR-10 Batch 5:  training cost: 0.2232 , validation accuracy: 0.7554
# Epoch 28, CIFAR-10 Batch 1:  training cost: 0.2858 , validation accuracy: 0.7414
# Epoch 28, CIFAR-10 Batch 2:  training cost: 0.2972 , validation accuracy: 0.7480
# Epoch 28, CIFAR-10 Batch 3:  training cost: 0.1962 , validation accuracy: 0.7472
# Epoch 28, CIFAR-10 Batch 4:  training cost: 0.2493 , validation accuracy: 0.7492
# Epoch 28, CIFAR-10 Batch 5:  training cost: 0.1839 , validation accuracy: 0.7460
# Epoch 29, CIFAR-10 Batch 1:  training cost: 0.3426 , validation accuracy: 0.7364
# Epoch 29, CIFAR-10 Batch 2:  training cost: 0.2778 , validation accuracy: 0.7396
# Epoch 29, CIFAR-10 Batch 3:  training cost: 0.2731 , validation accuracy: 0.7434
# Epoch 29, CIFAR-10 Batch 4:  training cost: 0.2233 , validation accuracy: 0.7500
# Epoch 29, CIFAR-10 Batch 5:  training cost: 0.2143 , validation accuracy: 0.7418
# Epoch 30, CIFAR-10 Batch 1:  training cost: 0.2642 , validation accuracy: 0.7446
# Epoch 30, CIFAR-10 Batch 2:  training cost: 0.2800 , validation accuracy: 0.7498
# Epoch 30, CIFAR-10 Batch 3:  training cost: 0.1843 , validation accuracy: 0.7432
# Epoch 30, CIFAR-10 Batch 4:  training cost: 0.1965 , validation accuracy: 0.7466
# Epoch 30, CIFAR-10 Batch 5:  training cost: 0.1752 , validation accuracy: 0.7532
# Epoch 31, CIFAR-10 Batch 1:  training cost: 0.2524 , validation accuracy: 0.7446
# Epoch 31, CIFAR-10 Batch 2:  training cost: 0.2469 , validation accuracy: 0.7572
# Epoch 31, CIFAR-10 Batch 3:  training cost: 0.1826 , validation accuracy: 0.7606
# Epoch 31, CIFAR-10 Batch 4:  training cost: 0.2149 , validation accuracy: 0.7384
# Epoch 31, CIFAR-10 Batch 5:  training cost: 0.1962 , validation accuracy: 0.7428
# Epoch 32, CIFAR-10 Batch 1:  training cost: 0.2625 , validation accuracy: 0.7584
# Epoch 32, CIFAR-10 Batch 2:  training cost: 0.2345 , validation accuracy: 0.7556
# Epoch 32, CIFAR-10 Batch 3:  training cost: 0.1647 , validation accuracy: 0.7538
# Epoch 32, CIFAR-10 Batch 4:  training cost: 0.1542 , validation accuracy: 0.7550
# Epoch 32, CIFAR-10 Batch 5:  training cost: 0.1557 , validation accuracy: 0.7458
# Epoch 33, CIFAR-10 Batch 1:  training cost: 0.2423 , validation accuracy: 0.7604
# Epoch 33, CIFAR-10 Batch 2:  training cost: 0.2152 , validation accuracy: 0.7520
# Epoch 33, CIFAR-10 Batch 3:  training cost: 0.1683 , validation accuracy: 0.7512
# Epoch 33, CIFAR-10 Batch 4:  training cost: 0.1833 , validation accuracy: 0.7492
# Epoch 33, CIFAR-10 Batch 5:  training cost: 0.2039 , validation accuracy: 0.7544
# Epoch 34, CIFAR-10 Batch 1:  training cost: 0.2331 , validation accuracy: 0.7566
# Epoch 34, CIFAR-10 Batch 2:  training cost: 0.2011 , validation accuracy: 0.7526
# Epoch 34, CIFAR-10 Batch 3:  training cost: 0.1234 , validation accuracy: 0.7502
# Epoch 34, CIFAR-10 Batch 4:  training cost: 0.1266 , validation accuracy: 0.7614
# Epoch 34, CIFAR-10 Batch 5:  training cost: 0.1493 , validation accuracy: 0.7534
# Epoch 35, CIFAR-10 Batch 1:  training cost: 0.2140 , validation accuracy: 0.7514
# Epoch 35, CIFAR-10 Batch 2:  training cost: 0.1979 , validation accuracy: 0.7632
# Epoch 35, CIFAR-10 Batch 3:  training cost: 0.1480 , validation accuracy: 0.7432
# Epoch 35, CIFAR-10 Batch 4:  training cost: 0.1266 , validation accuracy: 0.7536
# Epoch 35, CIFAR-10 Batch 5:  training cost: 0.1813 , validation accuracy: 0.7448
# Epoch 36, CIFAR-10 Batch 1:  training cost: 0.2022 , validation accuracy: 0.7534
# Epoch 36, CIFAR-10 Batch 2:  training cost: 0.2361 , validation accuracy: 0.7602
# Epoch 36, CIFAR-10 Batch 3:  training cost: 0.1669 , validation accuracy: 0.7644
# Epoch 36, CIFAR-10 Batch 4:  training cost: 0.1223 , validation accuracy: 0.7620
# Epoch 36, CIFAR-10 Batch 5:  training cost: 0.1752 , validation accuracy: 0.7594
# Epoch 37, CIFAR-10 Batch 1:  training cost: 0.2048 , validation accuracy: 0.7512
# Epoch 37, CIFAR-10 Batch 2:  training cost: 0.1809 , validation accuracy: 0.7604
# Epoch 37, CIFAR-10 Batch 3:  training cost: 0.1272 , validation accuracy: 0.7620
# Epoch 37, CIFAR-10 Batch 4:  training cost: 0.1628 , validation accuracy: 0.7616
# Epoch 37, CIFAR-10 Batch 5:  training cost: 0.1572 , validation accuracy: 0.7628
# Epoch 38, CIFAR-10 Batch 1:  training cost: 0.1760 , validation accuracy: 0.7454
# Epoch 38, CIFAR-10 Batch 2:  training cost: 0.1982 , validation accuracy: 0.7658
# Epoch 38, CIFAR-10 Batch 3:  training cost: 0.1408 , validation accuracy: 0.7570
# Epoch 38, CIFAR-10 Batch 4:  training cost: 0.1427 , validation accuracy: 0.7654
# Epoch 38, CIFAR-10 Batch 5:  training cost: 0.1566 , validation accuracy: 0.7660
# Epoch 39, CIFAR-10 Batch 1:  training cost: 0.2347 , validation accuracy: 0.7596
# Epoch 39, CIFAR-10 Batch 2:  training cost: 0.1689 , validation accuracy: 0.7584
# Epoch 39, CIFAR-10 Batch 3:  training cost: 0.1415 , validation accuracy: 0.7680
# Epoch 39, CIFAR-10 Batch 4:  training cost: 0.1097 , validation accuracy: 0.7728
# Epoch 39, CIFAR-10 Batch 5:  training cost: 0.1624 , validation accuracy: 0.7538
# Epoch 40, CIFAR-10 Batch 1:  training cost: 0.1664 , validation accuracy: 0.7708
# Epoch 40, CIFAR-10 Batch 2:  training cost: 0.2184 , validation accuracy: 0.7540
# Epoch 40, CIFAR-10 Batch 3:  training cost: 0.1297 , validation accuracy: 0.7708
# Epoch 40, CIFAR-10 Batch 4:  training cost: 0.1180 , validation accuracy: 0.7678
# Epoch 40, CIFAR-10 Batch 5:  training cost: 0.1651 , validation accuracy: 0.7624
# Epoch 41, CIFAR-10 Batch 1:  training cost: 0.1678 , validation accuracy: 0.7660
# Epoch 41, CIFAR-10 Batch 2:  training cost: 0.1305 , validation accuracy: 0.7674
# Epoch 41, CIFAR-10 Batch 3:  training cost: 0.1623 , validation accuracy: 0.7584
# Epoch 41, CIFAR-10 Batch 4:  training cost: 0.0980 , validation accuracy: 0.7714
# Epoch 41, CIFAR-10 Batch 5:  training cost: 0.1610 , validation accuracy: 0.7532
# Epoch 42, CIFAR-10 Batch 1:  training cost: 0.1359 , validation accuracy: 0.7698
# Epoch 42, CIFAR-10 Batch 2:  training cost: 0.1764 , validation accuracy: 0.7680
# Epoch 42, CIFAR-10 Batch 3:  training cost: 0.1536 , validation accuracy: 0.7706
# Epoch 42, CIFAR-10 Batch 4:  training cost: 0.0834 , validation accuracy: 0.7694
# Epoch 42, CIFAR-10 Batch 5:  training cost: 0.1133 , validation accuracy: 0.7628
# Epoch 43, CIFAR-10 Batch 1:  training cost: 0.1296 , validation accuracy: 0.7626
# Epoch 43, CIFAR-10 Batch 2:  training cost: 0.1261 , validation accuracy: 0.7674
# Epoch 43, CIFAR-10 Batch 3:  training cost: 0.0987 , validation accuracy: 0.7672
# Epoch 43, CIFAR-10 Batch 4:  training cost: 0.1274 , validation accuracy: 0.7552
# Epoch 43, CIFAR-10 Batch 5:  training cost: 0.0963 , validation accuracy: 0.7658
# Epoch 44, CIFAR-10 Batch 1:  training cost: 0.1209 , validation accuracy: 0.7580
# Epoch 44, CIFAR-10 Batch 2:  training cost: 0.1489 , validation accuracy: 0.7714
# Epoch 44, CIFAR-10 Batch 3:  training cost: 0.1105 , validation accuracy: 0.7716
# Epoch 44, CIFAR-10 Batch 4:  training cost: 0.0843 , validation accuracy: 0.7566
# Epoch 44, CIFAR-10 Batch 5:  training cost: 0.1067 , validation accuracy: 0.7712
# Epoch 45, CIFAR-10 Batch 1:  training cost: 0.1320 , validation accuracy: 0.7588
# Epoch 45, CIFAR-10 Batch 2:  training cost: 0.1237 , validation accuracy: 0.7580
# Epoch 45, CIFAR-10 Batch 3:  training cost: 0.1355 , validation accuracy: 0.7670
# Epoch 45, CIFAR-10 Batch 4:  training cost: 0.0776 , validation accuracy: 0.7628
# Epoch 45, CIFAR-10 Batch 5:  training cost: 0.0854 , validation accuracy: 0.7568
# Epoch 46, CIFAR-10 Batch 1:  training cost: 0.1370 , validation accuracy: 0.7556
# Epoch 46, CIFAR-10 Batch 2:  training cost: 0.1192 , validation accuracy: 0.7698
# Epoch 46, CIFAR-10 Batch 3:  training cost: 0.1540 , validation accuracy: 0.7608
# Epoch 46, CIFAR-10 Batch 4:  training cost: 0.1005 , validation accuracy: 0.7594
# Epoch 46, CIFAR-10 Batch 5:  training cost: 0.1092 , validation accuracy: 0.7728
# Epoch 47, CIFAR-10 Batch 1:  training cost: 0.0917 , validation accuracy: 0.7652
# Epoch 47, CIFAR-10 Batch 2:  training cost: 0.1231 , validation accuracy: 0.7634
# Epoch 47, CIFAR-10 Batch 3:  training cost: 0.1264 , validation accuracy: 0.7644
# Epoch 47, CIFAR-10 Batch 4:  training cost: 0.0827 , validation accuracy: 0.7722
# Epoch 47, CIFAR-10 Batch 5:  training cost: 0.1101 , validation accuracy: 0.7620
# Epoch 48, CIFAR-10 Batch 1:  training cost: 0.1065 , validation accuracy: 0.7480
# Epoch 48, CIFAR-10 Batch 2:  training cost: 0.1217 , validation accuracy: 0.7660
# Epoch 48, CIFAR-10 Batch 3:  training cost: 0.1303 , validation accuracy: 0.7642
# Epoch 48, CIFAR-10 Batch 4:  training cost: 0.0820 , validation accuracy: 0.7692
# Epoch 48, CIFAR-10 Batch 5:  training cost: 0.0822 , validation accuracy: 0.7666
# Epoch 49, CIFAR-10 Batch 1:  training cost: 0.0887 , validation accuracy: 0.7658
# Epoch 49, CIFAR-10 Batch 2:  training cost: 0.1113 , validation accuracy: 0.7732
# Epoch 49, CIFAR-10 Batch 3:  training cost: 0.1380 , validation accuracy: 0.7710
# Epoch 49, CIFAR-10 Batch 4:  training cost: 0.0915 , validation accuracy: 0.7614
# Epoch 49, CIFAR-10 Batch 5:  training cost: 0.1018 , validation accuracy: 0.7700
# Epoch 50, CIFAR-10 Batch 1:  training cost: 0.1378 , validation accuracy: 0.7714
# Epoch 50, CIFAR-10 Batch 2:  training cost: 0.1221 , validation accuracy: 0.7668
# Epoch 50, CIFAR-10 Batch 3:  training cost: 0.1060 , validation accuracy: 0.7620
# Epoch 50, CIFAR-10 Batch 4:  training cost: 0.0890 , validation accuracy: 0.7678
# Epoch 50, CIFAR-10 Batch 5:  training cost: 0.0658 , validation accuracy: 0.7712
# Epoch 51, CIFAR-10 Batch 1:  training cost: 0.0831 , validation accuracy: 0.7530
# Epoch 51, CIFAR-10 Batch 2:  training cost: 0.1047 , validation accuracy: 0.7736
# Epoch 51, CIFAR-10 Batch 3:  training cost: 0.0959 , validation accuracy: 0.7654
# Epoch 51, CIFAR-10 Batch 4:  training cost: 0.0951 , validation accuracy: 0.7766
# Epoch 51, CIFAR-10 Batch 5:  training cost: 0.0746 , validation accuracy: 0.7748
# Epoch 52, CIFAR-10 Batch 1:  training cost: 0.0991 , validation accuracy: 0.7550
# Epoch 52, CIFAR-10 Batch 2:  training cost: 0.1111 , validation accuracy: 0.7756
# Epoch 52, CIFAR-10 Batch 3:  training cost: 0.0873 , validation accuracy: 0.7682
# Epoch 52, CIFAR-10 Batch 4:  training cost: 0.0867 , validation accuracy: 0.7752
# Epoch 52, CIFAR-10 Batch 5:  training cost: 0.0828 , validation accuracy: 0.7724
# Epoch 53, CIFAR-10 Batch 1:  training cost: 0.1298 , validation accuracy: 0.7626
# Epoch 53, CIFAR-10 Batch 2:  training cost: 0.0814 , validation accuracy: 0.7758
# Epoch 53, CIFAR-10 Batch 3:  training cost: 0.0725 , validation accuracy: 0.7706
# Epoch 53, CIFAR-10 Batch 4:  training cost: 0.0787 , validation accuracy: 0.7694
# Epoch 53, CIFAR-10 Batch 5:  training cost: 0.0523 , validation accuracy: 0.7736
# Epoch 54, CIFAR-10 Batch 1:  training cost: 0.1007 , validation accuracy: 0.7712
# Epoch 54, CIFAR-10 Batch 2:  training cost: 0.1028 , validation accuracy: 0.7666
# Epoch 54, CIFAR-10 Batch 3:  training cost: 0.0696 , validation accuracy: 0.7806
# Epoch 54, CIFAR-10 Batch 4:  training cost: 0.0770 , validation accuracy: 0.7630
# Epoch 54, CIFAR-10 Batch 5:  training cost: 0.0573 , validation accuracy: 0.7720
# Epoch 55, CIFAR-10 Batch 1:  training cost: 0.0863 , validation accuracy: 0.7676
# Epoch 55, CIFAR-10 Batch 2:  training cost: 0.0961 , validation accuracy: 0.7824
# Epoch 55, CIFAR-10 Batch 3:  training cost: 0.0811 , validation accuracy: 0.7802
# Epoch 55, CIFAR-10 Batch 4:  training cost: 0.0669 , validation accuracy: 0.7762
# Epoch 55, CIFAR-10 Batch 5:  training cost: 0.0668 , validation accuracy: 0.7756
# Epoch 56, CIFAR-10 Batch 1:  training cost: 0.0765 , validation accuracy: 0.7632
# Epoch 56, CIFAR-10 Batch 2:  training cost: 0.0772 , validation accuracy: 0.7734
# Epoch 56, CIFAR-10 Batch 3:  training cost: 0.0624 , validation accuracy: 0.7660
# Epoch 56, CIFAR-10 Batch 4:  training cost: 0.0627 , validation accuracy: 0.7756
# Epoch 56, CIFAR-10 Batch 5:  training cost: 0.0620 , validation accuracy: 0.7796
# Epoch 57, CIFAR-10 Batch 1:  training cost: 0.1056 , validation accuracy: 0.7734
# Epoch 57, CIFAR-10 Batch 2:  training cost: 0.1017 , validation accuracy: 0.7722
# Epoch 57, CIFAR-10 Batch 3:  training cost: 0.0696 , validation accuracy: 0.7666
# Epoch 57, CIFAR-10 Batch 4:  training cost: 0.0834 , validation accuracy: 0.7766
# Epoch 57, CIFAR-10 Batch 5:  training cost: 0.0786 , validation accuracy: 0.7776
# Epoch 58, CIFAR-10 Batch 1:  training cost: 0.0960 , validation accuracy: 0.7620
# Epoch 58, CIFAR-10 Batch 2:  training cost: 0.0878 , validation accuracy: 0.7778
# Epoch 58, CIFAR-10 Batch 3:  training cost: 0.0675 , validation accuracy: 0.7764
# Epoch 58, CIFAR-10 Batch 4:  training cost: 0.0678 , validation accuracy: 0.7758
# Epoch 58, CIFAR-10 Batch 5:  training cost: 0.0448 , validation accuracy: 0.7710
# Epoch 59, CIFAR-10 Batch 1:  training cost: 0.0683 , validation accuracy: 0.7710
# Epoch 59, CIFAR-10 Batch 2:  training cost: 0.0619 , validation accuracy: 0.7706
# Epoch 59, CIFAR-10 Batch 3:  training cost: 0.0586 , validation accuracy: 0.7724
# Epoch 59, CIFAR-10 Batch 4:  training cost: 0.0884 , validation accuracy: 0.7774
# Epoch 59, CIFAR-10 Batch 5:  training cost: 0.0464 , validation accuracy: 0.7720
# Epoch 60, CIFAR-10 Batch 1:  training cost: 0.1010 , validation accuracy: 0.7780
# Epoch 60, CIFAR-10 Batch 2:  training cost: 0.0790 , validation accuracy: 0.7778
# Epoch 60, CIFAR-10 Batch 3:  training cost: 0.0495 , validation accuracy: 0.7742
# Epoch 60, CIFAR-10 Batch 4:  training cost: 0.0560 , validation accuracy: 0.7740
# Epoch 60, CIFAR-10 Batch 5:  training cost: 0.0543 , validation accuracy: 0.7670
# Epoch 61, CIFAR-10 Batch 1:  training cost: 0.0779 , validation accuracy: 0.7698
# Epoch 61, CIFAR-10 Batch 2:  training cost: 0.0956 , validation accuracy: 0.7688
# Epoch 61, CIFAR-10 Batch 3:  training cost: 0.0780 , validation accuracy: 0.7762
# Epoch 61, CIFAR-10 Batch 4:  training cost: 0.0549 , validation accuracy: 0.7688
# Epoch 61, CIFAR-10 Batch 5:  training cost: 0.0482 , validation accuracy: 0.7686
# Epoch 62, CIFAR-10 Batch 1:  training cost: 0.0715 , validation accuracy: 0.7518
# Epoch 62, CIFAR-10 Batch 2:  training cost: 0.0705 , validation accuracy: 0.7730
# Epoch 62, CIFAR-10 Batch 3:  training cost: 0.0662 , validation accuracy: 0.7604
# Epoch 62, CIFAR-10 Batch 4:  training cost: 0.0554 , validation accuracy: 0.7808
# Epoch 62, CIFAR-10 Batch 5:  training cost: 0.0705 , validation accuracy: 0.7806
# Epoch 63, CIFAR-10 Batch 1:  training cost: 0.0607 , validation accuracy: 0.7782
# Epoch 63, CIFAR-10 Batch 2:  training cost: 0.0690 , validation accuracy: 0.7728
# Epoch 63, CIFAR-10 Batch 3:  training cost: 0.0331 , validation accuracy: 0.7762
# Epoch 63, CIFAR-10 Batch 4:  training cost: 0.0726 , validation accuracy: 0.7780
# Epoch 63, CIFAR-10 Batch 5:  training cost: 0.0708 , validation accuracy: 0.7676
# Epoch 64, CIFAR-10 Batch 1:  training cost: 0.0747 , validation accuracy: 0.7712
# Epoch 64, CIFAR-10 Batch 2:  training cost: 0.0772 , validation accuracy: 0.7766
# Epoch 64, CIFAR-10 Batch 3:  training cost: 0.0481 , validation accuracy: 0.7756
# Epoch 64, CIFAR-10 Batch 4:  training cost: 0.0513 , validation accuracy: 0.7832
# Epoch 64, CIFAR-10 Batch 5:  training cost: 0.0498 , validation accuracy: 0.7794
# Epoch 65, CIFAR-10 Batch 1:  training cost: 0.0636 , validation accuracy: 0.7746
# Epoch 65, CIFAR-10 Batch 2:  training cost: 0.0689 , validation accuracy: 0.7840
# Epoch 65, CIFAR-10 Batch 3:  training cost: 0.0747 , validation accuracy: 0.7758
# Epoch 65, CIFAR-10 Batch 4:  training cost: 0.0550 , validation accuracy: 0.7754
# Epoch 65, CIFAR-10 Batch 5:  training cost: 0.0458 , validation accuracy: 0.7824
# Epoch 66, CIFAR-10 Batch 1:  training cost: 0.0698 , validation accuracy: 0.7738
# Epoch 66, CIFAR-10 Batch 2:  training cost: 0.0631 , validation accuracy: 0.7760
# Epoch 66, CIFAR-10 Batch 3:  training cost: 0.0535 , validation accuracy: 0.7824
# Epoch 66, CIFAR-10 Batch 4:  training cost: 0.0492 , validation accuracy: 0.7740
# Epoch 66, CIFAR-10 Batch 5:  training cost: 0.0541 , validation accuracy: 0.7742
# Epoch 67, CIFAR-10 Batch 1:  training cost: 0.0560 , validation accuracy: 0.7770
# Epoch 67, CIFAR-10 Batch 2:  training cost: 0.0593 , validation accuracy: 0.7754
# Epoch 67, CIFAR-10 Batch 3:  training cost: 0.0468 , validation accuracy: 0.7818
# Epoch 67, CIFAR-10 Batch 4:  training cost: 0.0403 , validation accuracy: 0.7806
# Epoch 67, CIFAR-10 Batch 5:  training cost: 0.0195 , validation accuracy: 0.7798
# Epoch 68, CIFAR-10 Batch 1:  training cost: 0.0666 , validation accuracy: 0.7760
# Epoch 68, CIFAR-10 Batch 2:  training cost: 0.0932 , validation accuracy: 0.7744
# Epoch 68, CIFAR-10 Batch 3:  training cost: 0.0554 , validation accuracy: 0.7724
# Epoch 68, CIFAR-10 Batch 4:  training cost: 0.0270 , validation accuracy: 0.7788
# Epoch 68, CIFAR-10 Batch 5:  training cost: 0.0367 , validation accuracy: 0.7730
# Epoch 69, CIFAR-10 Batch 1:  training cost: 0.0806 , validation accuracy: 0.7770
# Epoch 69, CIFAR-10 Batch 2:  training cost: 0.0641 , validation accuracy: 0.7794
# Epoch 69, CIFAR-10 Batch 3:  training cost: 0.0528 , validation accuracy: 0.7810
# Epoch 69, CIFAR-10 Batch 4:  training cost: 0.0402 , validation accuracy: 0.7846
# Epoch 69, CIFAR-10 Batch 5:  training cost: 0.0655 , validation accuracy: 0.7712
# Epoch 70, CIFAR-10 Batch 1:  training cost: 0.0527 , validation accuracy: 0.7810
# Epoch 70, CIFAR-10 Batch 2:  training cost: 0.0512 , validation accuracy: 0.7886
# Epoch 70, CIFAR-10 Batch 3:  training cost: 0.0572 , validation accuracy: 0.7716
# Epoch 70, CIFAR-10 Batch 4:  training cost: 0.0593 , validation accuracy: 0.7762
# Epoch 70, CIFAR-10 Batch 5:  training cost: 0.0323 , validation accuracy: 0.7764
# Epoch 71, CIFAR-10 Batch 1:  training cost: 0.0543 , validation accuracy: 0.7884
# Epoch 71, CIFAR-10 Batch 2:  training cost: 0.0534 , validation accuracy: 0.7796
# Epoch 71, CIFAR-10 Batch 3:  training cost: 0.0429 , validation accuracy: 0.7818
# Epoch 71, CIFAR-10 Batch 4:  training cost: 0.0297 , validation accuracy: 0.7798
# Epoch 71, CIFAR-10 Batch 5:  training cost: 0.0516 , validation accuracy: 0.7780
# Epoch 72, CIFAR-10 Batch 1:  training cost: 0.0487 , validation accuracy: 0.7746
# Epoch 72, CIFAR-10 Batch 2:  training cost: 0.0392 , validation accuracy: 0.7810
# Epoch 72, CIFAR-10 Batch 3:  training cost: 0.0395 , validation accuracy: 0.7830
# Epoch 72, CIFAR-10 Batch 4:  training cost: 0.0386 , validation accuracy: 0.7812
# Epoch 72, CIFAR-10 Batch 5:  training cost: 0.0323 , validation accuracy: 0.7790
# Epoch 73, CIFAR-10 Batch 1:  training cost: 0.0992 , validation accuracy: 0.7758
# Epoch 73, CIFAR-10 Batch 2:  training cost: 0.0623 , validation accuracy: 0.7724
# Epoch 73, CIFAR-10 Batch 3:  training cost: 0.0399 , validation accuracy: 0.7694
# Epoch 73, CIFAR-10 Batch 4:  training cost: 0.0292 , validation accuracy: 0.7814
# Epoch 73, CIFAR-10 Batch 5:  training cost: 0.0286 , validation accuracy: 0.7850
# Epoch 74, CIFAR-10 Batch 1:  training cost: 0.0652 , validation accuracy: 0.7750
# Epoch 74, CIFAR-10 Batch 2:  training cost: 0.0420 , validation accuracy: 0.7808
# Epoch 74, CIFAR-10 Batch 3:  training cost: 0.0425 , validation accuracy: 0.7800
# Epoch 74, CIFAR-10 Batch 4:  training cost: 0.0293 , validation accuracy: 0.7748
# Epoch 74, CIFAR-10 Batch 5:  training cost: 0.0282 , validation accuracy: 0.7838
# Epoch 75, CIFAR-10 Batch 1:  training cost: 0.0611 , validation accuracy: 0.7800
# Epoch 75, CIFAR-10 Batch 2:  training cost: 0.0492 , validation accuracy: 0.7766
# Epoch 75, CIFAR-10 Batch 3:  training cost: 0.0311 , validation accuracy: 0.7738
# Epoch 75, CIFAR-10 Batch 4:  training cost: 0.0340 , validation accuracy: 0.7722
# Epoch 75, CIFAR-10 Batch 5:  training cost: 0.0370 , validation accuracy: 0.7594
# Epoch 76, CIFAR-10 Batch 1:  training cost: 0.0467 , validation accuracy: 0.7734
# Epoch 76, CIFAR-10 Batch 2:  training cost: 0.0445 , validation accuracy: 0.7862
# Epoch 76, CIFAR-10 Batch 3:  training cost: 0.0366 , validation accuracy: 0.7806
# Epoch 76, CIFAR-10 Batch 4:  training cost: 0.0379 , validation accuracy: 0.7750
# Epoch 76, CIFAR-10 Batch 5:  training cost: 0.0294 , validation accuracy: 0.7768
# Epoch 77, CIFAR-10 Batch 1:  training cost: 0.0770 , validation accuracy: 0.7740
# Epoch 77, CIFAR-10 Batch 2:  training cost: 0.0403 , validation accuracy: 0.7856
# Epoch 77, CIFAR-10 Batch 3:  training cost: 0.0305 , validation accuracy: 0.7772
# Epoch 77, CIFAR-10 Batch 4:  training cost: 0.0487 , validation accuracy: 0.7732
# Epoch 77, CIFAR-10 Batch 5:  training cost: 0.0327 , validation accuracy: 0.7804
# Epoch 78, CIFAR-10 Batch 1:  training cost: 0.0662 , validation accuracy: 0.7830
# Epoch 78, CIFAR-10 Batch 2:  training cost: 0.0340 , validation accuracy: 0.7866
# Epoch 78, CIFAR-10 Batch 3:  training cost: 0.0334 , validation accuracy: 0.7756
# Epoch 78, CIFAR-10 Batch 4:  training cost: 0.0228 , validation accuracy: 0.7760
# Epoch 78, CIFAR-10 Batch 5:  training cost: 0.0398 , validation accuracy: 0.7756
# Epoch 79, CIFAR-10 Batch 1:  training cost: 0.0378 , validation accuracy: 0.7852
# Epoch 79, CIFAR-10 Batch 2:  training cost: 0.0419 , validation accuracy: 0.7798
# Epoch 79, CIFAR-10 Batch 3:  training cost: 0.0243 , validation accuracy: 0.7718
# Epoch 79, CIFAR-10 Batch 4:  training cost: 0.0234 , validation accuracy: 0.7726
# Epoch 79, CIFAR-10 Batch 5:  training cost: 0.0354 , validation accuracy: 0.7832
# Epoch 80, CIFAR-10 Batch 1:  training cost: 0.0425 , validation accuracy: 0.7784
# Epoch 80, CIFAR-10 Batch 2:  training cost: 0.0342 , validation accuracy: 0.7874
# Epoch 80, CIFAR-10 Batch 3:  training cost: 0.0315 , validation accuracy: 0.7792
# Epoch 80, CIFAR-10 Batch 4:  training cost: 0.0268 , validation accuracy: 0.7744
# Epoch 80, CIFAR-10 Batch 5:  training cost: 0.0278 , validation accuracy: 0.7788
# Epoch 81, CIFAR-10 Batch 1:  training cost: 0.0424 , validation accuracy: 0.7838
# Epoch 81, CIFAR-10 Batch 2:  training cost: 0.0511 , validation accuracy: 0.7888
# Epoch 81, CIFAR-10 Batch 3:  training cost: 0.0461 , validation accuracy: 0.7742
# Epoch 81, CIFAR-10 Batch 4:  training cost: 0.0210 , validation accuracy: 0.7814
# Epoch 81, CIFAR-10 Batch 5:  training cost: 0.0242 , validation accuracy: 0.7816
# Epoch 82, CIFAR-10 Batch 1:  training cost: 0.0405 , validation accuracy: 0.7814
# Epoch 82, CIFAR-10 Batch 2:  training cost: 0.0324 , validation accuracy: 0.7784
# Epoch 82, CIFAR-10 Batch 3:  training cost: 0.0321 , validation accuracy: 0.7804
# Epoch 82, CIFAR-10 Batch 4:  training cost: 0.0164 , validation accuracy: 0.7888
# Epoch 82, CIFAR-10 Batch 5:  training cost: 0.0206 , validation accuracy: 0.7844
# Epoch 83, CIFAR-10 Batch 1:  training cost: 0.0414 , validation accuracy: 0.7772
# Epoch 83, CIFAR-10 Batch 2:  training cost: 0.0334 , validation accuracy: 0.7784
# Epoch 83, CIFAR-10 Batch 3:  training cost: 0.0325 , validation accuracy: 0.7708
# Epoch 83, CIFAR-10 Batch 4:  training cost: 0.0259 , validation accuracy: 0.7846
# Epoch 83, CIFAR-10 Batch 5:  training cost: 0.0233 , validation accuracy: 0.7870
# Epoch 84, CIFAR-10 Batch 1:  training cost: 0.0385 , validation accuracy: 0.7828
# Epoch 84, CIFAR-10 Batch 2:  training cost: 0.0342 , validation accuracy: 0.7812
# Epoch 84, CIFAR-10 Batch 3:  training cost: 0.0450 , validation accuracy: 0.7736
# Epoch 84, CIFAR-10 Batch 4:  training cost: 0.0155 , validation accuracy: 0.7848
# Epoch 84, CIFAR-10 Batch 5:  training cost: 0.0151 , validation accuracy: 0.7836
# Epoch 85, CIFAR-10 Batch 1:  training cost: 0.0533 , validation accuracy: 0.7740
# Epoch 85, CIFAR-10 Batch 2:  training cost: 0.0383 , validation accuracy: 0.7848
# Epoch 85, CIFAR-10 Batch 3:  training cost: 0.0392 , validation accuracy: 0.7736
# Epoch 85, CIFAR-10 Batch 4:  training cost: 0.0233 , validation accuracy: 0.7850
# Epoch 85, CIFAR-10 Batch 5:  training cost: 0.0438 , validation accuracy: 0.7826
# Epoch 86, CIFAR-10 Batch 1:  training cost: 0.0393 , validation accuracy: 0.7782
# Epoch 86, CIFAR-10 Batch 2:  training cost: 0.0382 , validation accuracy: 0.7902
# Epoch 86, CIFAR-10 Batch 3:  training cost: 0.0451 , validation accuracy: 0.7790
# Epoch 86, CIFAR-10 Batch 4:  training cost: 0.0191 , validation accuracy: 0.7838
# Epoch 86, CIFAR-10 Batch 5:  training cost: 0.0354 , validation accuracy: 0.7836
# Epoch 87, CIFAR-10 Batch 1:  training cost: 0.0340 , validation accuracy: 0.7790
# Epoch 87, CIFAR-10 Batch 2:  training cost: 0.0367 , validation accuracy: 0.7876
# Epoch 87, CIFAR-10 Batch 3:  training cost: 0.0267 , validation accuracy: 0.7654
# Epoch 87, CIFAR-10 Batch 4:  training cost: 0.0216 , validation accuracy: 0.7800
# Epoch 87, CIFAR-10 Batch 5:  training cost: 0.0141 , validation accuracy: 0.7808
# Epoch 88, CIFAR-10 Batch 1:  training cost: 0.0459 , validation accuracy: 0.7820
# Epoch 88, CIFAR-10 Batch 2:  training cost: 0.0288 , validation accuracy: 0.7814
# Epoch 88, CIFAR-10 Batch 3:  training cost: 0.0472 , validation accuracy: 0.7702
# Epoch 88, CIFAR-10 Batch 4:  training cost: 0.0488 , validation accuracy: 0.7752
# Epoch 88, CIFAR-10 Batch 5:  training cost: 0.0202 , validation accuracy: 0.7794
# Epoch 89, CIFAR-10 Batch 1:  training cost: 0.0342 , validation accuracy: 0.7896
# Epoch 89, CIFAR-10 Batch 2:  training cost: 0.0415 , validation accuracy: 0.7860
# Epoch 89, CIFAR-10 Batch 3:  training cost: 0.0129 , validation accuracy: 0.7832
# Epoch 89, CIFAR-10 Batch 4:  training cost: 0.0368 , validation accuracy: 0.7860
# Epoch 89, CIFAR-10 Batch 5:  training cost: 0.0158 , validation accuracy: 0.7838
# Epoch 90, CIFAR-10 Batch 1:  training cost: 0.0234 , validation accuracy: 0.7868
# Epoch 90, CIFAR-10 Batch 2:  training cost: 0.0467 , validation accuracy: 0.7856
# Epoch 90, CIFAR-10 Batch 3:  training cost: 0.0353 , validation accuracy: 0.7806
# Epoch 90, CIFAR-10 Batch 4:  training cost: 0.0351 , validation accuracy: 0.7846
# Epoch 90, CIFAR-10 Batch 5:  training cost: 0.0121 , validation accuracy: 0.7846
# Epoch 91, CIFAR-10 Batch 1:  training cost: 0.0226 , validation accuracy: 0.7900
# Epoch 91, CIFAR-10 Batch 2:  training cost: 0.0378 , validation accuracy: 0.7844
# Epoch 91, CIFAR-10 Batch 3:  training cost: 0.0253 , validation accuracy: 0.7854
# Epoch 91, CIFAR-10 Batch 4:  training cost: 0.0218 , validation accuracy: 0.7868
# Epoch 91, CIFAR-10 Batch 5:  training cost: 0.0181 , validation accuracy: 0.7916
# Epoch 92, CIFAR-10 Batch 1:  training cost: 0.0305 , validation accuracy: 0.7790
# Epoch 92, CIFAR-10 Batch 2:  training cost: 0.0362 , validation accuracy: 0.7842
# Epoch 92, CIFAR-10 Batch 3:  training cost: 0.0357 , validation accuracy: 0.7628
# Epoch 92, CIFAR-10 Batch 4:  training cost: 0.0166 , validation accuracy: 0.7892
# Epoch 92, CIFAR-10 Batch 5:  training cost: 0.0208 , validation accuracy: 0.7858
# Epoch 93, CIFAR-10 Batch 1:  training cost: 0.0207 , validation accuracy: 0.7858
# Epoch 93, CIFAR-10 Batch 2:  training cost: 0.0517 , validation accuracy: 0.7762
# Epoch 93, CIFAR-10 Batch 3:  training cost: 0.0243 , validation accuracy: 0.7876
# Epoch 93, CIFAR-10 Batch 4:  training cost: 0.0453 , validation accuracy: 0.7802
# Epoch 93, CIFAR-10 Batch 5:  training cost: 0.0205 , validation accuracy: 0.7848
# Epoch 94, CIFAR-10 Batch 1:  training cost: 0.0276 , validation accuracy: 0.7758
# Epoch 94, CIFAR-10 Batch 2:  training cost: 0.0277 , validation accuracy: 0.7900
# Epoch 94, CIFAR-10 Batch 3:  training cost: 0.0126 , validation accuracy: 0.7876
# Epoch 94, CIFAR-10 Batch 4:  training cost: 0.0179 , validation accuracy: 0.7892
# Epoch 94, CIFAR-10 Batch 5:  training cost: 0.0186 , validation accuracy: 0.7890
# Epoch 95, CIFAR-10 Batch 1:  training cost: 0.0285 , validation accuracy: 0.7930
# Epoch 95, CIFAR-10 Batch 2:  training cost: 0.0228 , validation accuracy: 0.7956
# Epoch 95, CIFAR-10 Batch 3:  training cost: 0.0175 , validation accuracy: 0.7864
# Epoch 95, CIFAR-10 Batch 4:  training cost: 0.0209 , validation accuracy: 0.7844
# Epoch 95, CIFAR-10 Batch 5:  training cost: 0.0117 , validation accuracy: 0.7904
# Epoch 96, CIFAR-10 Batch 1:  training cost: 0.0232 , validation accuracy: 0.7914
# Epoch 96, CIFAR-10 Batch 2:  training cost: 0.0237 , validation accuracy: 0.7870
# Epoch 96, CIFAR-10 Batch 3:  training cost: 0.0101 , validation accuracy: 0.7824
# Epoch 96, CIFAR-10 Batch 4:  training cost: 0.0293 , validation accuracy: 0.7854
# Epoch 96, CIFAR-10 Batch 5:  training cost: 0.0178 , validation accuracy: 0.7856
# Epoch 97, CIFAR-10 Batch 1:  training cost: 0.0251 , validation accuracy: 0.7904
# Epoch 97, CIFAR-10 Batch 2:  training cost: 0.0343 , validation accuracy: 0.7848
# Epoch 97, CIFAR-10 Batch 3:  training cost: 0.0149 , validation accuracy: 0.7762
# Epoch 97, CIFAR-10 Batch 4:  training cost: 0.0389 , validation accuracy: 0.7900
# Epoch 97, CIFAR-10 Batch 5:  training cost: 0.0223 , validation accuracy: 0.7774
# Epoch 98, CIFAR-10 Batch 1:  training cost: 0.0465 , validation accuracy: 0.7856
# Epoch 98, CIFAR-10 Batch 2:  training cost: 0.0153 , validation accuracy: 0.7854
# Epoch 98, CIFAR-10 Batch 3:  training cost: 0.0140 , validation accuracy: 0.7814
# Epoch 98, CIFAR-10 Batch 4:  training cost: 0.0294 , validation accuracy: 0.7720
# Epoch 98, CIFAR-10 Batch 5:  training cost: 0.0244 , validation accuracy: 0.7866
# Epoch 99, CIFAR-10 Batch 1:  training cost: 0.0394 , validation accuracy: 0.7840
# Epoch 99, CIFAR-10 Batch 2:  training cost: 0.0231 , validation accuracy: 0.7866
# Epoch 99, CIFAR-10 Batch 3:  training cost: 0.0229 , validation accuracy: 0.7822
# Epoch 99, CIFAR-10 Batch 4:  training cost: 0.0280 , validation accuracy: 0.7856
# Epoch 99, CIFAR-10 Batch 5:  training cost: 0.0281 , validation accuracy: 0.7784
# Epoch 100, CIFAR-10 Batch 1:  training cost: 0.0152 , validation accuracy: 0.7880
# Epoch 100, CIFAR-10 Batch 2:  training cost: 0.0240 , validation accuracy: 0.7826
# Epoch 100, CIFAR-10 Batch 3:  training cost: 0.0116 , validation accuracy: 0.7868
# Epoch 100, CIFAR-10 Batch 4:  training cost: 0.0154 , validation accuracy: 0.7878
# Epoch 100, CIFAR-10 Batch 5:  training cost: 0.0122 , validation accuracy: 0.7852

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.7708662974683544

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
